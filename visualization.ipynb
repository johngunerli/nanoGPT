# %%
import matplotlib.pyplot as plt

# Data for visualization
steps = [0, 25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500]
train_loss = [10.8706, 3.2835, 2.6638, 2.5392, 2.4906, 2.4512, 2.4172, 2.3785, 2.3129, 2.2426, 2.1776, 2.1067, 2.0278, 1.9777, 1.9327, 1.9039, 1.8719, 1.8490, 1.8213, 1.8049, 1.7950]
val_loss = [10.8701, 3.3269, 2.6677, 2.5364, 2.4955, 2.4733, 2.4399, 2.3929, 2.3450, 2.2943, 2.2354, 2.1794, 2.1150, 2.0866, 2.0507, 2.0173, 1.9964, 1.9970, 1.9698, 1.9493, 1.9475]

# %%
# Creating the plot
plt.figure(figsize=(10, 6))
plt.plot(steps, train_loss, label='Train Loss', color='blue', marker='o')
plt.plot(steps, val_loss, label='Validation Loss', color='red', marker='o')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Steps')
plt.legend()
plt.grid(True)
plt.show()
